# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_data=pd.read_csv('titanic.csv')

# %% [markdown]
# # Exploratory Data Analysis

# %%
titanic_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
titanic_data.shape
# Out:
# (891, 12)

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic_data.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
titanic_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.countplot(data=titanic_data,x='Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
figure, axes=plt.subplots(1,2,figsize=(15,5))
sns.countplot(data=titanic_data,x='Sex',ax=axes[0])
sns.countplot(data=titanic_data,x='Sex',hue='Survived',ax=axes[1])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
figure, axes=plt.subplots(1,2,figsize=(15,5))
sns.countplot(data=titanic_data,x='Pclass',ax=axes[0])
sns.countplot(data=titanic_data,x='Pclass',hue='Survived',ax=axes[1])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
figure, axes=plt.subplots(1,2,figsize=(15,5))
sns.countplot(data=titanic_data,x='Embarked',ax=axes[0])
sns.countplot(data=titanic_data,x='Embarked',hue='Survived',ax=axes[1])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
figure, axes=plt.subplots(1,2,figsize=(15,5))
sns.countplot(data=titanic_data,x='SibSp',ax=axes[0])
sns.countplot(data=titanic_data,x='SibSp',hue='Survived',ax=axes[1])
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
figure, axes=plt.subplots(1,2,figsize=(15,5))
sns.countplot(data=titanic_data,x='Parch',ax=axes[0])
sns.countplot(data=titanic_data,x='Parch',hue='Survived',ax=axes[1])
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
figure, axes=plt.subplots(1,2,figsize=(15,5))
sns.histplot(data=titanic_data,x='Age',kde=True,ax=axes[0])
sns.histplot(data=titanic_data,x='Age',hue='Survived',ax=axes[1])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
figure, axes=plt.subplots(1,2,figsize=(15,5))
sns.histplot(data=titanic_data,x='Fare',kde=True,ax=axes[0])
sns.histplot(data=titanic_data,x='Fare',hue='Survived',ax=axes[1])
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %% [markdown]
# #Correlation Check

# %%
grid = sns.FacetGrid(titanic_data, col='Survived', row='Pclass', height=3.0,aspect=2.0)
grid.map(plt.hist,'Age',bins=20)
grid.add_legend();
# Out:
# C:\Users\User\anaconda\envs\mbdiploma\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
grid = sns.FacetGrid(titanic_data, col='Survived', row='Embarked', height=3.0,aspect=2.0)
grid.map(plt.hist,'Age',bins=20)
grid.add_legend();
# Out:
# C:\Users\User\anaconda\envs\mbdiploma\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
titanic_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data=titanic_data.drop(columns=['PassengerId','Name','Ticket'])
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0         0       3    male  22.0      1      0   7.2500   NaN        S
# 1         1       1  female  38.0      1      0  71.2833   C85        C
# 2         1       3  female  26.0      0      0   7.9250   NaN        S
# 3         1       1  female  35.0      1      0  53.1000  C123        S
# 4         0       3    male  35.0      0      0   8.0500   NaN        S

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
data=data.drop(columns=['Cabin'])

# %% [markdown]
# # Dummy values

# %%
from sklearn.preprocessing import LabelEncoder
data['Sex']=LabelEncoder().fit_transform(data['Sex'])
data['Embarked']=LabelEncoder().fit_transform(data['Embarked'])
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0         0       3    1  22.0      1      0   7.2500         2
# 1         1       1    0  38.0      1      0  71.2833         0
# 2         1       3    0  26.0      0      0   7.9250         2
# 3         1       1    0  35.0      1      0  53.1000         2
# 4         0       3    1  35.0      0      0   8.0500         2

# %% [markdown]
# # Cleaning Missing Values

# %%
data.shape
# Out:
# (891, 8)

# %%
data.dropna(inplace=True)
data.shape
# Out:
# (714, 8)

# %%
 data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
ax=sns.heatmap(data.corr(),annot=True)

# %%
print(data.corr())
# Out:
#           Survived    Pclass       Sex       Age     SibSp     Parch  \
# Survived  1.000000 -0.359653 -0.538826 -0.077221 -0.017358  0.093317
# Pclass   -0.359653  1.000000  0.155460 -0.369226  0.067247  0.025683
# Sex      -0.538826  0.155460  1.000000  0.093254 -0.103950 -0.246972
# Age      -0.077221 -0.369226  0.093254  1.000000 -0.308247 -0.189119
# SibSp    -0.017358  0.067247 -0.103950 -0.308247  1.000000  0.383820
# Parch     0.093317  0.025683 -0.246972 -0.189119  0.383820  1.000000
# Fare      0.268189 -0.554182 -0.184994  0.096067  0.138329  0.205119
# Embarked -0.174692  0.234857  0.102239 -0.025252  0.030121  0.009197
#
#               Fare  Embarked
# Survived  0.268189 -0.174692
# Pclass   -0.554182  0.234857
# Sex      -0.184994  0.102239
# Age       0.096067 -0.025252
# SibSp     0.138329  0.030121
# Parch     0.205119  0.009197
# Fare      1.000000 -0.277620
# Embarked -0.277620  1.000000

# %% [markdown]
# # Split Train and Test Data

# %%
x=data.drop(columns='Survived')
y=data['Survived']

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)
x_train.shape
# Out:
# (499, 7)

# %%
x_test.shape
# Out:
# (215, 7)

# %% [markdown]
# # Train Models

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
lg=LogisticRegression()
knn=KNeighborsClassifier()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
sv=SVC()
gb=GaussianNB()

# %%
lg.fit(x_train,y_train)
knn.fit(x_train,y_train)
dt.fit(x_train,y_train)
rf.fit(x_train,y_train)
sv.fit(x_train,y_train)
gb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
print('Train model accuracy score')
print('LogisticRegression: ',lg.score(x_train,y_train))
print('K-Neighbors: ' ,knn.score(x_train,y_train))
print('Decision Tree: ',dt.score(x_train,y_train))
print('Random Forest: ',rf.score(x_train,y_train))
print('Support Vector: ',sv.score(x_train,y_train))
print('Gaussian NB: ',gb.score(x_train,y_train))
# Out:
# Train model accuracy score
# LogisticRegression:  0.7975951903807615
# K-Neighbors:  0.7875751503006012
# Decision Tree:  0.9919839679358717
# Random Forest:  0.9919839679358717
# Support Vector:  0.6893787575150301
# Gaussian NB:  0.7955911823647295

# %% [markdown]
# # Model Prediction Accuracy

# %%
lg_pred=lg.predict(x_test)
knn_pred=knn.predict(x_test)
dt_pred=dt.predict(x_test)
rf_pred=rf.predict(x_test)
sv_pred=sv.predict(x_test)
gb_pred=gb.predict(x_test)

# %%
from sklearn import metrics

# %%
print('Prediction Accuracy')
print('LogisticRegression: ',metrics.accuracy_score(y_test,lg_pred))
print('K-Neighbors: ' ,metrics.accuracy_score(y_test,knn_pred))
print('Decision Tree: ',metrics.accuracy_score(y_test,dt_pred))
print('Random Forest: ',metrics.accuracy_score(y_test,rf_pred))
print('Support Vector: ',metrics.accuracy_score(y_test,sv_pred))
print('Gaussian NB: ',metrics.accuracy_score(y_test,gb_pred))
# Out:
# Prediction Accuracy
# LogisticRegression:  0.8232558139534883
# K-Neighbors:  0.641860465116279
# Decision Tree:  0.7534883720930232
# Random Forest:  0.7627906976744186
# Support Vector:  0.6511627906976745
# Gaussian NB:  0.7767441860465116

# %%
print("F1 Score")
print("Logistic: ",metrics.f1_score(y_test,lg_pred))
print("K-Neighbors: ",metrics.f1_score(y_test,knn_pred))
print("Decision Tree: ",metrics.f1_score(y_test,dt_pred))
print("Random Forest: ",metrics.f1_score(y_test,rf_pred))
print("Support Vector: ",metrics.f1_score(y_test,sv_pred))
print("Gaussian NB: ",metrics.f1_score(y_test,gb_pred))
# Out:
# F1 Score
# Logistic:  0.7816091954022989
# K-Neighbors:  0.5497076023391813
# Decision Tree:  0.707182320441989
# Random Forest:  0.7085714285714285
# Support Vector:  0.4444444444444444
# Gaussian NB:  0.7176470588235294

# %%
from sklearn.naive_bayes import BernoulliNB
bb=BernoulliNB()
bb.fit(x_train,y_train)
bb.score(x_train,y_train)
# Out:
# 0.7735470941883767

# %%
bb_pred=bb.predict(x_test)
metrics.accuracy_score(y_test,bb_pred)
# Out:
# 0.7767441860465116

# %%
metrics.f1_score(y_test,bb_pred)
# Out:
# 0.7303370786516853

# %%
from sklearn.preprocessing import RobustScaler
x=RobustScaler().fit_transform(x)
